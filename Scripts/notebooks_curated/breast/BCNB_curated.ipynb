# %%
# %reload_ext autoreload
# %autoreload 2

import sys
import os

sys.path.append(os.path.abspath("../.."))

# %%
from AnalysisConfig import AnalysisConfig
from DatasetAnalyzer import DatasetAnalyzer

#C:\Users\vicen\Repositories\Tesis\Scripts\output_norm

config = AnalysisConfig(
    file_path="2_metadata_BCNB_curated.csv",
    output_dir="outputs_curated_breast",
    dataset_name="BCNB_curated",

    include_columns=["ER_status_norm","PR_status_norm","HER2_status_norm","Ki67_percent","Ki67_cat", "Molecular subtype", "Age(years)"],
    force_categorical=["ER_status_norm","PR_status_norm","HER2_status_norm","Ki67_percent","Ki67_cat", "Molecular subtype"],

    column_value_mapping={
        "ER_status_norm": {
            1: "Positive",
            0: "Negative"
        },"PR_status_norm": {
            1: "Positive",
            0: "Negative"
        },"HER2_status_norm": {
            0: "0/1+",
            1: "2+",
            2:"3+",
        }
    },   

    save_reports=True,
    save_cleaned_data=True,
    save_plots=True,
    show_plots=True
)

analyzer = DatasetAnalyzer(config)
reports = analyzer.run()
