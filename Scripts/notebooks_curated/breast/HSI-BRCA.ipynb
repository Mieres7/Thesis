# %%
# %reload_ext autoreload
# %autoreload 2

import sys
import os

sys.path.append(os.path.abspath("../.."))

# %%
from AnalysisConfig import AnalysisConfig
from DatasetAnalyzer import DatasetAnalyzer

#C:\Users\vicen\Repositories\Tesis\Scripts\output_norm

config = AnalysisConfig(
    file_path="7_metadata_HSI-BRCA-2_curated.xlsx",
    output_dir="outputs_curated_breast",
    dataset_name="HSI-BRCA_curated",
    file_type='xlsx',

    include_columns=["ER_status_norm","PR_status_norm","HER2_status_norm","KI67","Ki67_cat", "Molecular_subtype", "Age at Diagnosis (Years)"],
    force_categorical=["ER_status_norm","PR_status_norm","HER2_status_norm","Ki67_cat", "KI67","Molecular_subtype"],

    column_value_mapping={
        "ER_status_norm": {
            1: "Positive",
            0: "Negative"
        },"PR_status_norm": {
            1: "Positive",
            0: "Negative"
        },"HER2_status_norm": {
            0: "0/1+",
            1: "2+",
            2:"3+",
        },"Molecular_subtype": {
            0: "Luminal A",
            1: "Luminal B",
            2:"Luminal B",
            3: "HER2+",
            4: "Triple Negative"
        },"KI67":{
            0: "KI67 index < 20%",
            1: "KI67 index >= 20%"
        }

    }, 

    save_reports=True,
    save_cleaned_data=True,
    save_plots=True,
    show_plots=True
)

analyzer = DatasetAnalyzer(config)
reports = analyzer.run()
