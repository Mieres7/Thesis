# %%
# %reload_ext autoreload
# %autoreload 2

import sys
import os

sys.path.append(os.path.abspath("../.."))

# %%
from AnalysisConfig import AnalysisConfig
from DatasetAnalyzer import DatasetAnalyzer

#C:\Users\vicen\Repositories\Tesis\Scripts\output_norm

config = AnalysisConfig(
    file_path="histai_colorectal_b2_metadata_regroup_norm.csv",
    output_dir="outputs_curated_colorectal",
    dataset_name="histai_b2_curated",

    include_columns=[
        "age",
        "gender",
        "site_group_norm",
        "side_norm",
        "lesion_class_norm",
        "hist_type_norm",
        "grade_norm",
        "pT_cat",
        "pN_cat",
        "pM_cat",
        "N_status_norm",
        "stage_simplified",
        "LN_examined_norm",
        "LN_positive_norm",
        "LVI_norm",
        "PNI_norm",
        "MMR_status_norm",
        "MSI_status_norm",
        "KRAS_status_norm",
        "NRAS_status_norm",
        "BRAF_status_norm",
        "death_5y_norm",
        "os_days_norm"
    ],
    force_categorical=["death_5y_norm"],

    # column_value_mapping={
    #     "ER_status_norm": {
    #         1: "Positive",
    #         0: "Negative"
    #     },"PR_status_norm": {
    #         1: "Positive",
    #         0: "Negative"
    #     },"HER2_status_norm": {
    #         0: "0/1+",
    #         1: "2+",
    #         2:"3+",
    #     }
    # },   

    save_reports=True,
    save_cleaned_data=True,
    save_plots=True,
    show_plots=True
)

analyzer = DatasetAnalyzer(config)
reports = analyzer.run()
# Out:
# c:\Users\vicen\Repositories\Tesis\Scripts\DatasetAnalyzer.py:274: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   datetime_try = pd.to_datetime(
# c:\Users\vicen\Repositories\Tesis\Scripts\DatasetAnalyzer.py:274: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   datetime_try = pd.to_datetime(
# c:\Users\vicen\Repositories\Tesis\Scripts\DatasetAnalyzer.py:274: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   datetime_try = pd.to_datetime(
# c:\Users\vicen\Repositories\Tesis\Scripts\DatasetAnalyzer.py:274: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   datetime_try = pd.to_datetime(
# c:\Users\vicen\Repositories\Tesis\Scripts\DatasetAnalyzer.py:274: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   datetime_try = pd.to_datetime(
# c:\Users\vicen\Repositories\Tesis\Scripts\DatasetAnalyzer.py:274: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   datetime_try = pd.to_datetime(
# c:\Users\vicen\Repositories\Tesis\Scripts\DatasetAnalyzer.py:274: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   datetime_try = pd.to_datetime(
